# %% [markdown]
# ## Interval variant count
#
# We would like to aggregate the data according to the intervals, to cehck how many variants there are in each interval <br>
# The following notebook shows 3 kind of interval analysis:
# 1. by GH associated DSD genes
# 2. by DSD genes which are 1mb from an interval
# 3. by genes which are 1.5mb from an interval
#
# In each analysis, 3 subgroups will be analysed -
# 1. all samples
# 2. samples diagnosed with DSD
#
# Ken's data and Sinclair data will be analysed seperately

# %%
import sys
import os
sys.path.append(os.path.abspath("code"))
# these are  needed-
import pandas as pd
from GnomAD_df_class import GnomAD_df

# %%
gdf = GnomAD_df(path='data/main_new_AF.prq',
                peak_file='data/hATAC_mATAC_peak.bed.gz',
                remove_unkown=True,
                remove_phased_gt=True,
                only_peak_variants=True)
sinclair_sample_data = pd.read_csv('data/pedigree_data.tsv', sep='\t')
sin_probands = sinclair_sample_data.id[sinclair_sample_data.fam_relation == 0].tolist() 
sin_non_probands = sinclair_sample_data.id[~sinclair_sample_data.id.isin(probands)] 
ken_probands =   [i for i in gdf.get_samples() if i.startswith('P') and i != 'PKGen169']
ken_non_probands = ['PKGen169']
interval_df = pd.read_csv('data/intervals_with_overlaps_1_1.5mb.csv', index_col=0).set_index('INTERVAL_ID')
# gdf.get_table().head()

# %% [markdown]
# We will start with sinclair data <br>
# first, we need to filter the main table to match the samples.

# %%
print(f'Sincalair data contains {len(sin_probands)} samples with DSD and \
{len(sin_non_probands)} without \n total- {len(sin_probands) +len(sin_non_probands)} variants')
# Out:
# Sincalair data contains 9 samples with DSD and 15 without
#  total- 24 variants

# %%
gdf.filter_samples([i for i in gdf.get_samples() if i not in sin_probands + sin_non_probands.tolist() ])
bool_df = gdf.bool_variant_df()
bool_df.head()
# Out:
# Filtering samples
# removing variants outside of peak interval
# removed unkwon genotypes (e.g "./.")
# replaced phased genotype (e.g "0|1" -> "0/1")
# done
#                         NEW_AF          INTERVAL_ID  AS22WG009  AS22WG010  \
# CHROM POS    REF ALT
# chr1  634112 T   C         NaN       PGRA.SER.GRA_1       True       True
#       778639 A   G    0.127933  PGRA.SER.GRA.PSER_2      False      False
#       779047 G   A    0.819806  PGRA.SER.GRA.PSER_2       True       True
#       826893 G   A    0.730133  PGRA.SER.GRA.PSER_3       True       True
#       827209 G   C    0.739536  PGRA.SER.GRA.PSER_3       True       True
#
#                       AS22WG011  AS22WG023  AS22WG024  AS22WG004  AS22WG005  \
# CHROM POS    REF ALT
# chr1  634112 T   C         True       True       True       True       True
#       778639 A   G        False      False      False      False      False
#       779047 G   A         True       True       True       True       True
#       826893 G   A         True       True       True       True       True
#       827209 G   C         True       True       True       True       True
#
#                       AS22WG006  ...  AS22WG013  AS22WG014  AS22WG015  \
# CHROM POS    REF ALT             ...
# chr1  634112 T   C         True  ...       True       True       True
#       778639 A   G        False  ...      False      False      False
#       779047 G   A         True  ...       True       True       True
#       826893 G   A         True  ...       True       True       True
#       827209 G   C         True  ...       True       True       True
#
#                       AS22WG016  AS22WG017  AS22WG018  AS22WG019  AS22WG020  \
# CHROM POS    REF ALT
# chr1  634112 T   C         True       True       True       True       True
#       778639 A   G        False      False      False      False      False
#       779047 G   A         True       True       True       True       True
#       826893 G   A         True       True       True       True       True
#       827209 G   C         True       True       True       True       True
#
#                       AS22WG021  AS22WG022
# CHROM POS    REF ALT
# chr1  634112 T   C         True       True
#       778639 A   G        False      False
#       779047 G   A         True       True
#       826893 G   A         True       True
#       827209 G   C         True       True
#
# [5 rows x 26 columns]

# %%
def get_numbers(bool_df,probands, non_probands, prefix='', AF_t=1):
    bool_df = bool_df[bool_df.NEW_AF <= AF_t]
    all_samples = bool_df.drop(columns='NEW_AF').groupby('INTERVAL_ID').sum().sum(axis=1).rename(prefix + 'all_samples')
    only_probands = bool_df.drop(columns=['NEW_AF'] + non_probands).groupby('INTERVAL_ID').sum().sum(axis=1).rename(prefix + 'only_probands')
    only_non_probands = bool_df.drop(columns=['NEW_AF'] + probands).groupby('INTERVAL_ID').sum().sum(axis=1).rename(prefix +'only_non_probands')
    return pd.DataFrame(data=[all_samples, only_probands, only_non_probands]).T

# sin_af1  = get_numbers(bool_df, sin_probands, sin_non_probands.tolist(),'sin_').sort_values('sin_all_samples', ascending=False)
# sin_aff =  get_numbers(bool_df, sin_probands, sin_non_probands.tolist(),'sin_af<0.01_', AF_t=0.01).sort_values('sin_af<0.01_all_samples', ascending=False)
# sin_aff.head()

# %%
sinclair = pd.concat([interval_df,sin_af1,sin_aff], axis=1).sort_values('sin_af<0.01_all_samples', ascending=False)

# %%
# gdf.reset_table().filter_samples([i for i in gdf.get_samples() if i not in ken_probands + ken_non_probands ])
# bool_df = gdf.bool_variant_df()
# bool_df.head()

ken_af1  = get_numbers(bool_df, ken_probands, ken_non_probands,'ken_')
ken_aff =  get_numbers(bool_df, ken_probands, ken_non_probands,'ken_af<0.01_', AF_t=0.01)
ken_aff.head()
# Out:
#              ken_af<0.01_all_samples  ken_af<0.01_only_probands  \
# INTERVAL_ID
# CM100017                           1                          1
# CM100097                           1                          1
# CM100099                           1                          0
# CM100102                           1                          1
# CM100109                           1                          1
#
#              ken_af<0.01_only_non_probands
# INTERVAL_ID
# CM100017                                 0
# CM100097                                 0
# CM100099                                 1
# CM100102                                 0
# CM100109                                 0

# %%
ken
# Out:
#                          CHROM      FROM        TO GH_DSD_genes  GH_DSD  \
# INTERVAL_ID
# PGRA.SER_6229            chr11   1015808   1017938          NaN   False
# mATAC_hATAC_32167         chr6  31355973  31357525          NaN   False
# mATAC_hATAC_32222         chr6  32583486  32584897          NaN   False
# mATAC_hATAC_32164         chr6  31270881  31272606          NaN   False
# PGRA.SER.PSER.GRA_28538   chr3  75667918  75670704          NaN   False
# ...                        ...       ...       ...          ...     ...
# SER_42024                 chrY  19743944  19745337          NaN   False
# SER.PSER_42025            chrY  20574998  20576299          NaN   False
# CM189619                  chrY  20753080  20753096          NaN   False
# CM189620                  chrY  57183942  57184105          NaN   False
# CM189621                  chrY  57184209  57184541          NaN   False
#
#                         dsd_genes1mb dsd_gene1.5mb  \
# INTERVAL_ID
# PGRA.SER_6229                    NaN          IGF2
# mATAC_hATAC_32167                NaN           NaN
# mATAC_hATAC_32222                NaN           NaN
# mATAC_hATAC_32164                NaN           NaN
# PGRA.SER.PSER.GRA_28538          NaN           NaN
# ...                              ...           ...
# SER_42024                        NaN           NaN
# SER.PSER_42025                   NaN           NaN
# CM189619                         NaN           NaN
# CM189620                         NaN           NaN
# CM189621                         NaN           NaN
#
#                                                             all_genes1.5mb  \
# INTERVAL_ID
# PGRA.SER_6229            WBP1LP10_OR4F2P_ENSG00000254468_CICP23_LINC010...
# mATAC_hATAC_32167        ENSG00000290870_HCP5B_ENSG00000230521_HLA-H_HL...
# mATAC_hATAC_32222        C6orf15_PSORS1C1_CDSN_PSORS1C2_POLR2LP1_CCHCR1...
# mATAC_hATAC_32164        HLA-V_HCG4_HLA-V_HLA-P_RPL7AP7_MICG_HLA-G_HCG4...
# PGRA.SER.PSER.GRA_28538  CNTN3_NIPA2P2_RN7SL294P_MIR4444-2_ENSG00000287...
# ...                                                                    ...
# SER_42024                TAF9P2_CLUHP2_FAM224A_ENSG00000278391_RNA5SP52...
# SER.PSER_42025           TTTY14_ENSG00000274282_GAPDHP19_BCORP1_BCORP1_...
# CM189619                 ENSG00000274282_GAPDHP19_BCORP1_BCORP1_TXLNGY_...
# CM189620                 CTBP2P1_AMD1P2_DPH3P2_VAMP7_ELOCP24_TRPC6P1_IL...
# CM189621                 CTBP2P1_AMD1P2_DPH3P2_VAMP7_ELOCP24_TRPC6P1_IL...
#
#                          num_of_genes  ken_all_samples  ken_only_probands  \
# INTERVAL_ID
# PGRA.SER_6229                     132             74.0               69.0
# mATAC_hATAC_32167                 210             66.0               60.0
# mATAC_hATAC_32222                 186             77.0               75.0
# mATAC_hATAC_32164                 215            192.0              171.0
# PGRA.SER.PSER.GRA_28538            41             69.0               66.0
# ...                               ...              ...                ...
# SER_42024                          33              NaN                NaN
# SER.PSER_42025                     38              NaN                NaN
# CM189619                           38              NaN                NaN
# CM189620                           11              NaN                NaN
# CM189621                           12              NaN                NaN
#
#                          ken_only_non_probands  ken_af<0.01_all_samples  \
# INTERVAL_ID
# PGRA.SER_6229                              5.0                     54.0
# mATAC_hATAC_32167                          6.0                     40.0
# mATAC_hATAC_32222                          2.0                     36.0
# mATAC_hATAC_32164                         21.0                     35.0
# PGRA.SER.PSER.GRA_28538                    3.0                     32.0
# ...                                        ...                      ...
# SER_42024                                  NaN                      NaN
# SER.PSER_42025                             NaN                      NaN
# CM189619                                   NaN                      NaN
# CM189620                                   NaN                      NaN
# CM189621                                   NaN                      NaN
#
#                          ken_af<0.01_only_probands  \
# INTERVAL_ID
# PGRA.SER_6229                                 53.0
# mATAC_hATAC_32167                             37.0
# mATAC_hATAC_32222                             34.0
# mATAC_hATAC_32164                             31.0
# PGRA.SER.PSER.GRA_28538                       31.0
# ...                                            ...
# SER_42024                                      NaN
# SER.PSER_42025                                 NaN
# CM189619                                       NaN
# CM189620                                       NaN
# CM189621                                       NaN
#
#                          ken_af<0.01_only_non_probands
# INTERVAL_ID
# PGRA.SER_6229                                      1.0
# mATAC_hATAC_32167                                  3.0
# mATAC_hATAC_32222                                  2.0
# mATAC_hATAC_32164                                  4.0
# PGRA.SER.PSER.GRA_28538                            1.0
# ...                                                ...
# SER_42024                                          NaN
# SER.PSER_42025                                     NaN
# CM189619                                           NaN
# CM189620                                           NaN
# CM189621                                           NaN
#
# [193680 rows x 15 columns]

# %%
ken = pd.concat([interval_df,ken_af1,ken_aff], axis=1).sort_values('ken_af<0.01_all_samples', ascending=False)

# %%
# create a excel writer object
with pd.ExcelWriter("outputs/interval_variants.xlsx") as writer:
   
    # use to_excel function and specify the sheet_name and index
    # to store the dataframe in specified sheet
    sinclair.to_excel(writer, sheet_name="sinclair")
    ken.to_excel(writer, sheet_name="ken")

# %%
# Out:
#                     INTERVAL_ID  CHROM       FROM         TO  \
# 0                 PGRA.SER_6229  chr11    1015808    1017938
# 1       PGRA.SER.PSER.GRA_28538   chr3   75667918   75670704
# 2       PGRA.SER.GRA.PSER_39577   chr9   62837274   62838738
# 3             mATAC_hATAC_22657   chr2  178193444  178195490
# 4              mATAC_hATAC_9960  chr12  108855616  108858272
# ...                         ...    ...        ...        ...
# 193675                SER_42024   chrY   19743944   19745337
# 193676           SER.PSER_42025   chrY   20574998   20576299
# 193677                 CM189619   chrY   20753080   20753096
# 193678                 CM189620   chrY   57183942   57184105
# 193679                 CM189621   chrY   57184209   57184541
#
#                GH_DSD_genes  GH_DSD dsd_genes1mb dsd_gene1.5mb  \
# 0                       NaN   False          NaN          IGF2
# 1                       NaN   False          NaN           NaN
# 2                       NaN   False          NaN           NaN
# 3                       NaN   False          NaN           NaN
# 4       ['SART3 : 23.5516']    True        SART3         SART3
# ...                     ...     ...          ...           ...
# 193675                  NaN   False          NaN           NaN
# 193676                  NaN   False          NaN           NaN
# 193677                  NaN   False          NaN           NaN
# 193678                  NaN   False          NaN           NaN
# 193679                  NaN   False          NaN           NaN
#
#                                            all_genes1.5mb  num_of_genes  \
# 0       WBP1LP10_OR4F2P_ENSG00000254468_CICP23_LINC010...           132
# 1       CNTN3_NIPA2P2_RN7SL294P_MIR4444-2_ENSG00000287...            41
# 2       CNTNAP3C_RN7SL462P_ENSG00000277109_FAM242D_Y_R...            65
# 3       LINC01117_ENSG00000230552_FUCA1P1_ENSG00000223...            52
# 4       ABTB3_ENSG00000200897_RNA5SP371_ENSG0000025757...            53
# ...                                                   ...           ...
# 193675  TAF9P2_CLUHP2_FAM224A_ENSG00000278391_RNA5SP52...            33
# 193676  TTTY14_ENSG00000274282_GAPDHP19_BCORP1_BCORP1_...            38
# 193677  ENSG00000274282_GAPDHP19_BCORP1_BCORP1_TXLNGY_...            38
# 193678  CTBP2P1_AMD1P2_DPH3P2_VAMP7_ELOCP24_TRPC6P1_IL...            11
# 193679  CTBP2P1_AMD1P2_DPH3P2_VAMP7_ELOCP24_TRPC6P1_IL...            12
#
#         sin_all_samples  sin_only_probands  sin_only_non_probands  \
# 0                  70.0               32.0                   38.0
# 1                 122.0               53.0                   69.0
# 2                  79.0               32.0                   47.0
# 3                  68.0               26.0                   42.0
# 4                  33.0               13.0                   20.0
# ...                 ...                ...                    ...
# 193675              NaN                NaN                    NaN
# 193676              NaN                NaN                    NaN
# 193677              NaN                NaN                    NaN
# 193678              NaN                NaN                    NaN
# 193679              NaN                NaN                    NaN
#
#         sin_af<0.01_all_samples  sin_af<0.01_only_probands  \
# 0                          38.0                       15.0
# 1                          33.0                       10.0
# 2                          31.0                       14.0
# 3                          25.0                       10.0
# 4                           3.0                        1.0
# ...                         ...                        ...
# 193675                      NaN                        NaN
# 193676                      NaN                        NaN
# 193677                      NaN                        NaN
# 193678                      NaN                        NaN
# 193679                      NaN                        NaN
#
#         sin_af<0.01_only_non_probands
# 0                                23.0
# 1                                23.0
# 2                                17.0
# 3                                15.0
# 4                                 2.0
# ...                               ...
# 193675                            NaN
# 193676                            NaN
# 193677                            NaN
# 193678                            NaN
# 193679                            NaN
#
# [193680 rows x 16 columns]
